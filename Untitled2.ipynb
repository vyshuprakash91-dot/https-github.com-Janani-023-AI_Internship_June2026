# %%
#pass
a=int(input("enter your number:"))
if a>18:

 pass
else:
  print (a)
# Out:
# enter your number:15
# 15

# %%
#string slicing
n="vyshnavi"
print(n[0:3])
# Out:
# vys

# %%
n="vyshnavi"
print(n[-3:-1])
# Out:
# av

# %%
n="vyshnavi"
print(n[ : :2])
# Out:
# vsnv

# %%
#case conversion
n="vyshnavi prakash"
print(n.upper())
print(n.lower())
print(n.capitalize())
print(n.title())
print(n.swapcase())
# Out:
# VYSHNAVI PRAKASH
# vyshnavi prakash
# Vyshnavi prakash
# Vyshnavi Prakash
# VYSHNAVI PRAKASH

# %%
#alignment and padding
n="vyshnavi"
print(n.center(30))
print(n.ljust(30))
print(n.rjust(30))
print("".zfill(4))
# Out:
#            vyshnavi
# vyshnavi
#                       vyshnavi
# 0000

# %%
#trimming and removing whilespace
n="     vyshnavi"
print(n.strip())
print(n.lstrip())
print(n.rstrip())
# Out:
# vyshnavi
# vyshnavi
#      vyshnavi

# %%
n="vysh navi"
print(n.split())
m="vyshn"
print(m.join(["hi","hello"]))
s="vyshnavi"
print(s.split("a"))
print("hi", "guys".partition("y"))
# Out:
# ['vysh', 'navi']
# hivyshnhello
# ['vyshn', 'vi']
# hi ('gu', 'y', 's')
