# %%
#id card
name=input("enter the name")
age=int(input("Enther the age"))
dep=(input("Enter the department"))
salary=int(input("Enter the salary"))
print("name:",name)
print("age:",age)
print("deparetment:",dep)
print("salary:",salary)
# Out:
# enter the namevyshu
# Enther the age18
# Enter the departmentcs
# Enter the salary10000
# name: vyshu
# age: 18
# deparetment: cs
# salary: 10000

# %%
#grocery bil
apple=int(input("iteam1"))
mango=int(input("iteam2"))
orange=int(input("iteam3"))
banana=int(input("iteam4"))
berry=int(input("iteam5"))
bill=(apple+mango+orange+banana+berry)
print("total",bill)
# Out:
# iteam170
# iteam280
# iteam390
# iteam4100
# iteam586
# total 426

# %%
#student marks
a=int(input("mark1"))
b=int(input("mark2"))
c=int(input("mark3"))
d=int(input("mark4"))
e=int(input("mark5"))
marks=a+b+c+d+e
print("total",marks)
# Out:
# mark190
# mark290
# mark390
# mark490
# mark590
# total 450

# %%
#temperture convert
a=float(input("celsius"))
b=a*(9/4)+48
print("fahrenheit=",b)
# Out:
# celsius10
# fahrenheit= 70.5

# %%
#mobile rechare
amount=float(input("recharge amount:"))
gst=float(input("gst%:"))
final=amount+(amount*gst/100)
print("total amount",final)
# Out:
# recharge amount:399
# gst%:5
# total amount 418.95

# %%
#account balance
a=float(input("enter blance"))
b=float(input("enter amount"))
if b<=a:
  print("sucess")
else:
  print("not sucess")
# Out:
# enter blance1000
# enter amount5000
# not sucess

# %%
#vote
age=int(input("enter the age"))
if age>=18:
 print("not eligble to vote")
else:
 print("eligble to vote")
